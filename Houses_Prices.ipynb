# %% [markdown]
# # House Price

# %% [markdown]
# ## Importing Libraries and Loading Data

# %%
# importitng libraries

import numpy as np
import pandas as pd
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})

from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
# loading data
data = pd.read_csv('houseprice.csv')

# Label price
y = data['SalePrice']

# drop the price from the data
data.drop(['SalePrice'], axis=1, inplace=True)

data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  ...  MoSold YrSold SaleType SaleCondition
# 0   1          60       RL         65.0  ...       2   2008       WD        Normal
# 1   2          20       RL         80.0  ...       5   2007       WD        Normal
# 2   3          60       RL         68.0  ...       9   2008       WD        Normal
# 3   4          70       RL         60.0  ...       2   2006       WD       Abnorml
# 4   5          60       RL         84.0  ...      12   2008       WD        Normal
#
# [5 rows x 80 columns]

# %%
data.shape
# Out:
# (1460, 80)

# %% [markdown]
# ## Data Preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Check count of null values
nulls = pd.isnull(data).sum()
nulls[nulls > 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
# Drop columns with alot of missing values
data = data.drop(['Id', 'Alley', 'MiscFeature', 'Fence', 'PoolQC', 'FireplaceQu'], axis = 1)
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          60       RL         65.0  ...    2008       WD        Normal
# 1          20       RL         80.0  ...    2007       WD        Normal
# 2          60       RL         68.0  ...    2008       WD        Normal
# 3          70       RL         60.0  ...    2006       WD       Abnorml
# 4          60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 74 columns]

# %%
# Check columns types
data.dtypes.value_counts()
# Out:
# object     38
# int64      33
# float64     3
# dtype: int64

# %%
# Handle missing values
features = data.columns
for feature in features:
    feature_type = str(data[feature].dtype)
    # Check if catigorical feature
    if feature_type is 'object':
        # replace catigorical values with the mode
        data[feature].fillna(data[feature].mode().iloc[0], inplace=True)
    else:
        # replace continous values with the mean
        data[feature].fillna(int(data[feature].mean()), inplace=True)

# %%
# Now there are on missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
# Convert catigorcal values
cat_features = [ x for x in data.columns if str(data[x].dtype) == 'object']
for feature in cat_features:
    hot_encoder = pd.get_dummies(data[feature])
    # drop one feature
    hot_encoder = hot_encoder.iloc[: , 1:]
    # drop cat feature
    data.drop(feature, axis=1, inplace=True)
    # add new features to the data
    data = data.join(hot_encoder,  lsuffix="_1", rsuffix="_2")

data.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  ...  Family  Normal  Partial
# 0          60         65.0     8450  ...       0       1        0
# 1          20         80.0     9600  ...       0       1        0
# 2          60         68.0    11250  ...       0       1        0
# 3          70         60.0     9550  ...       0       0        0
# 4          60         84.0    14260  ...       0       1        0
#
# [5 rows x 232 columns]

# %% [markdown]
# ## Dimentionality Reduction

# %%
# Now apply PCA To the data
pca = PCA(n_components=36,whiten=True)
pca = pca.fit(data)
dataPCA = pca.transform(data)
dataPCA.shape
# Out:
# (1460, 36)

# %% [markdown]
# ## Modeling

# %%
# Data after PCA
X = dataPCA

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size = .2, random_state = 42)

# %%
# Define the models
lin_reg = LinearRegression()
bag_reg = BaggingRegressor()
dec_reg = DecisionTreeRegressor()
ran_reg = RandomForestRegressor()
svm_reg = SVR(kernel='linear')

models = {'Linear Regression' : lin_reg,
          'Bagging Regression' : bag_reg,
          'Decision Tree' : dec_reg,
          'Support Vector Regressor' : ran_reg,
          'Random Forest Regressor' : ran_reg}

# %%
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    score = model.score(X_test,y_test) * 100
    results[name] = score

# %%
Scores = pd.DataFrame({
    'Model': results.keys(),
    'Score': results.values()})
Scores.sort_values(by='Score', ascending=False)
# Out:
#                       Model      Score
# 0         Linear Regression  83.491867
# 1        Bagging Regression  80.831788
# 4   Random Forest Regressor  80.044325
# 3  Support Vector Regressor  79.941753
# 2             Decision Tree  62.120934

# %%
sns.barplot(data=Scores, x='Model', y='Score')
